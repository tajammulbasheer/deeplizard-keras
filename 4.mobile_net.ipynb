# %% [markdown]
# #### MobileNet

# %%
import keras
import numpy as np
from keras import utils
from keras.applications import imagenet_utils

# %%
mobile = keras.applications.mobilenet.MobileNet()

# %%
def prepare_image(file):
    img_path = 'data/images/'
    img = utils.load_img(img_path + file, target_size=(224, 224))
    img_array = utils.img_to_array(img)
    img_array_expanded_dims = np.expand_dims(img_array, axis=0)
    return keras.applications.mobilenet.preprocess_input(img_array_expanded_dims)

# %%
from IPython.display import Image
Image(filename='data/images/dog.jpg', width=300,height=200)

# %%
preprocessed_image = prepare_image('dog.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# 1/1 [==============================] - 0s 67ms/step
# [[('n02090379', 'redbone', 0.98371464),
#   ('n02100583', 'vizsla', 0.0062747756),
#   ('n02089867', 'Walker_hound', 0.0038211038),
#   ('n02087394', 'Rhodesian_ridgeback', 0.0019160177),
#   ('n02089973', 'English_foxhound', 0.0016142551)]]

# %%
Image(filename='data/images/cat.jpg', width=300,height=200)

# %%
preprocessed_image = prepare_image('cat.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# 1/1 [==============================] - 0s 72ms/step
# [[('n02123597', 'Siamese_cat', 0.50213426),
#   ('n02124075', 'Egyptian_cat', 0.2567771),
#   ('n02127052', 'lynx', 0.10094893),
#   ('n03887697', 'paper_towel', 0.04006757),
#   ('n02123159', 'tiger_cat', 0.029420204)]]

# %%
Image(filename='data/images/park.jpg', width=300,height=200)

# %%
preprocessed_image = prepare_image('park.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# 1/1 [==============================] - 0s 77ms/step
# [[('n03837869', 'obelisk', 0.36425284),
#   ('n04562935', 'water_tower', 0.12692854),
#   ('n03028079', 'church', 0.076230325),
#   ('n03877845', 'palace', 0.06993721),
#   ('n02980441', 'castle', 0.044883)]]
